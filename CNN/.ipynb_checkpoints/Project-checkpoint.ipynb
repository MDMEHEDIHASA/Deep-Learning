# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
import os

# %%
data_dir = 'D:\drowsing'

# %%
os.listdir(data_dir)
# Out:
# ['test dataset', 'train dataset']

# %%
from matplotlib.image import imread

# %%
test_path = data_dir+'\\test dataset\\'
train_path = data_dir+'\\train dataset\\'

# %%
test_path
# Out:
# 'D:\\drowsing\\test dataset\\'

# %%
os.listdir(test_path)
# Out:
# ['close eye', 'open eye']

# %%
os.listdir(train_path)
# Out:
# ['close eye', 'open eye']

# %%
#os.listdir(train_path+'close eye')

# %%
#get the first one
os.listdir(train_path+'close eye')[0]
# Out:
# 's0001_00001_0_0_0_0_0_01.png'

# %%
close_eye_path = train_path+'close eye\\'+'s0001_00001_0_0_0_0_0_01.png'

# %%
close_eye_path
# Out:
# 'D:\\drowsing\\train dataset\\close eye\\s0001_00001_0_0_0_0_0_01.png'

# %%
imread(close_eye_path)
# Out:
# array([[0.14901961, 0.16078432, 0.17254902, ..., 0.34901962, 0.34901962,
#         0.34901962],
#        [0.14901961, 0.16078432, 0.17254902, ..., 0.36078432, 0.36078432,
#         0.35686275],
#        [0.14901961, 0.16078432, 0.16862746, ..., 0.36862746, 0.3647059 ,
#         0.3647059 ],
#        ...,
#        [0.20392157, 0.21176471, 0.23529412, ..., 0.30588236, 0.30588236,
#         0.3137255 ],
#        [0.2       , 0.20784314, 0.23137255, ..., 0.31764707, 0.31764707,
#         0.31764707],
#        [0.2       , 0.2       , 0.21568628, ..., 0.3137255 , 0.3137255 ,
#         0.32156864]], dtype=float32)

# %%
imread(close_eye_path).shape
# Out:
# (86, 86)

# %%
plt.imshow(imread(close_eye_path))

# %%
os.listdir(train_path+'open eye')[5]
# Out:
# 's0001_01847_0_0_1_0_0_01.png'

# %%
openeyePath = train_path+'open eye\\'+'s0001_01847_0_0_1_0_0_01.png'

# %%
imread(openeyePath).shape
# Out:
# (78, 78)

# %%
plt.imshow(imread(openeyePath))

# %%
#check how many image in train
len(os.listdir(train_path+'open eye'))
# Out:
# 21936

# %%
#check how many image in test
len(os.listdir(train_path+'close eye'))
# Out:
# 21936

# %%
dim1 = []
dim2 = []

for image_filename in os.listdir(test_path+'open eye'):
    img  = imread(test_path+'open eye\\'+image_filename)
    d1,d2 = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
#dim1

# %%
sns.jointplot(x=dim1,y=dim2)

# %%
np.mean(dim1)
# Out:
# 73.18168604651163

# %%
np.mean(dim2)
# Out:
# 73.18168604651163

# %%
image_shape = (73,73,3)

# %%
73*73*1
# Out:
# 5329

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
imread(openeyePath).max()
# Out:
# 0.38431373

# %%
para_img = imread(openeyePath)
plt.imshow(para_img)

# %%
image_gen = ImageDataGenerator(rotation_range=20,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               rescale=1/255,
                               shear_range=0.1,
                               zoom_range=0.1,
                               horizontal_flip=True,
                               fill_mode='nearest'
                               
                              )

# %%
plt.imshow(image_gen.random_transform(openeyePath))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-62b8909a5b89> in <module>
# ----> 1 plt.imshow(image_gen.random_transform(openeyePath))
#
# ~\anaconda3\lib\site-packages\keras_preprocessing\image\image_data_generator.py in random_transform(self, x, seed)
#     900             A randomly transformed version of the input (same shape).
#     901         """
# --> 902         params = self.get_random_transform(x.shape, seed)
#     903         return self.apply_transform(x, params)
#     904
#
# AttributeError: 'str' object has no attribute 'shape'

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 43872 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 4128 images belonging to 2 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,Flatten,Dropout

# %%
#what is image_shape its in line no 27
model = Sequential()

model.add(Conv2D(filters=32,kernel_size=(3,3),input_shape= image_shape,activation='relu',))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape= image_shape,activation='relu',))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape= image_shape,activation='relu',))
model.add(MaxPool2D(pool_size=(2,2)))



model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 71, 71, 32)        896
#
#  max_pooling2d_6 (MaxPooling  (None, 35, 35, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 33, 33, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_8 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 128)               401536
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 457,985
# Trainable params: 457,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=1)

# %%
batch_size=18
image_shape
# Out:
# (73, 73, 3)

# %%
image_shape[:2]
# Out:
# (73, 73)

# %%
train_image_gen = image_gen.flow_from_directory(train_path,target_size=image_shape[:2],
                                                color_mode='rgb',batch_size=batch_size,
                                                class_mode='binary'
                                               )
# Out:
# Found 43872 images belonging to 2 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,target_size=image_shape[:2],
                                                color_mode='rgb',batch_size=batch_size,
                                                class_mode='binary',shuffle=False
                                               )
# Out:
# Found 4128 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'close eye': 0, 'open eye': 1}

# %%
results = model.fit(train_image_gen,epochs=20,validation_data=test_image_gen,callbacks=[early_stop])
# Out:
# Epoch 1/20
# 2438/2438 [==============================] - 287s 118ms/step - loss: 0.2360 - accuracy: 0.9049 - val_loss: 0.1916 - val_accuracy: 0.9402
# Epoch 2/20
# 2438/2438 [==============================] - 290s 119ms/step - loss: 0.1179 - accuracy: 0.9578 - val_loss: 0.0803 - val_accuracy: 0.9729
# Epoch 3/20
# 2438/2438 [==============================] - 298s 122ms/step - loss: 0.0922 - accuracy: 0.9674 - val_loss: 0.1605 - val_accuracy: 0.9477

# %%
from tensorflow.keras.models import load_model

# %%
model.save('drowsinessModel.h5')

# %%
pd.DataFrame(model.history.history)
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.236010  0.904882  0.191597      0.940165
# 1  0.117909  0.957809  0.080309      0.972868
# 2  0.092184  0.967382  0.160485      0.947674

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses[['loss','val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
losses[['accuracy','val_accuracy']].plot()
# Out:
# <AxesSubplot:>

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
model.evaluate(test_image_gen)
# Out:
# 230/230 [==============================] - 11s 47ms/step - loss: 0.1591 - accuracy: 0.9467
# [0.15914064645767212, 0.9467054009437561]

# %%
from tensorflow.keras.preprocessing import image

# %%
pred_probabilities = model.predict(test_image_gen)

# %%
pred_probabilities
# Out:
# array([[0.07524332],
#        [0.02619207],
#        [0.0026629 ],
#        ...,
#        [0.37676787],
#        [0.8326745 ],
#        [0.7019666 ]], dtype=float32)

# %%
test_image_gen.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
predictions = pred_probabilities > 0.7

# %%
# Numpy can treat this as True/False for us
predictions
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [ True]])

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(test_image_gen.classes,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      2064
#            1       1.00      0.84      0.91      2064
#
#     accuracy                           0.92      4128
#    macro avg       0.93      0.92      0.92      4128
# weighted avg       0.93      0.92      0.92      4128

# %%
confusion_matrix(test_image_gen.classes,predictions)
# Out:
# array([[2058,    6],
#        [ 329, 1735]], dtype=int64)

# %%
os.listdir(test_path+'open eye')[5]
# Out:
# 's0027_00546_0_1_1_0_0_01.png'

# %%
close_eye_path_test = test_path+'open eye\\'+'s0027_00546_0_1_1_0_0_01.png'

# %%
close_eye_path_test
# Out:
# 'D:\\drowsing\\test dataset\\open eye\\s0027_00546_0_1_1_0_0_01.png'

# %%
my_image = image.load_img(close_eye_path_test,target_size=image_shape)

# %%
my_image
# Out:
# <PIL.Image.Image image mode=RGB size=73x73 at 0x14C07CDCFA0>

# %%
type(my_image)
# Out:
# PIL.Image.Image

# %%
my_image = image.img_to_array(my_image)

# %%
my_image.shape
# Out:
# (73, 73, 3)

# %%
my_image = np.expand_dims(my_image, axis=0)

# %%
my_image.shape
# Out:
# (1, 73, 73, 3)

# %%
model.predict(my_image)
# Out:
# array([[0.]], dtype=float32)

# %%
train_image_gen.class_indices
# Out:
# {'close eye': 0, 'open eye': 1}
